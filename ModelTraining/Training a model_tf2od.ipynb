# %% [markdown]
# # How-to train a model on Azure ML
#
# This notebook takes you through the steps of training a model on Azure ML for The Ocean Cleanup. We train the models through Azure ML to provide us with a good registration of all performed tests, so that we can see why and how a model was created.
#
# When the result of a training run is satisfactory, a model can be registered from there, from which point we can deploy it.
#
# There are a few concepts to know about first:
#
# - Workspace: The entire AzureML environment you are working in. The Workspace contains all the other elements.
# - Experiment: A collection of Runs (see below). A logical container for training a model with different parameters to determine the best.
# - Run: A single train/test run of a model. These are tied to an experiment. If you want to train the same model with different parameters, so you can compare them, these are different runs under the same experiment.
# - Environment: The code environment used by your code. This contains things like the required Python packages. Multiple options exist here - from just using your local environment to completely curated environments directly from Azure.
# - Dataset: A single dataset as registered in the AzureML workspace.
#
# With that out of the way, lets dive right in. Looking at these components, our first step will be to get the correct Workspace:

# %%
from toc_azurewrapper.workspace import get_workspace

subscription_id = "a00eaec6-b320-4e7c-ae61-60a30aec1cfc"
resource_group = "MachineLearning"
workspace_name = "tutorial_azureml_mats"
tenant_id = "86f9fea7-9eb0-4325-8b58-7ed0db623956"

workspace = get_workspace(subscription_id, resource_group, workspace_name, tenant_id=tenant_id)

# %% [markdown]
# ## Create experiment
#
# Now that we have a workspace available, we need to create an experiment. As describe above, an experiment will be the container for multiple runs, in which we can train and compare the model using different parameters.
#
# The experiment needs a name. Use something that is descriptive and clear to anyone seeing this.

# %%
from toc_azurewrapper.train import create_experiment
experiment = create_experiment(workspace, "model-tf2od-jayke")

# %% [markdown]
# ## Create or select compute target
#
# We want to train our model on a GPU cluster on AzureML. Lets create one (or load an existing one).

# %%
from toc_azurewrapper.compute import get_compute

compute_target = get_compute(workspace, "gpu-cluster-ai", vm_size='STANDARD_NC6', max_nodes=1)
# compute_target = get_compute(workspace, "gpu-cluster-v100", vm_size='STANDARD_NC6S_V3', max_nodes=1)
# compute_target = get_compute(workspace, "gpu-cluster", vm_size='STANDARD_NC6', max_nodes=4)
# Out:
# Found existing compute target

# %% [markdown]
# ## Create the environment
#
# We will now need to create an environment. In this case, we build our own from a Docker file.

# %%
from toc_azurewrapper.environment import get_environment


environment = get_environment(
     workspace,
    "tensorflow-objectdetection",
     docker_file="./examples/tensorflow/Dockerfile"
)
# Out:
# No environment with that name found, creating new one

# %% [markdown]
# ## Prepare model wraper
#
# Now it's time to perform our first Run of the experiment. However, before we can do this, we will need a wrapper around our model. This wrapper needs to do a few things:
#
# - Initialize and train the model with:
#   - The desired parameters
#   - The desired data
# - Evaluate the performance of the trained model
# - Register the parameters and the performance in the Run object
# - Add the generated model artifacts to the Run object
#
# There is skeleton code for this available: `skeleton_files/train.py`. In this file you fill in what parameters you expect, you create and train and evaluate the model using these parameters and the loaded in dataset(s), and you register the results and the created artifacts with the Run.
#
# For this how-to, we will use the example provided in `examples/frcnn/train.py`. This is an implementation of the file mentioned above. It expects two parameters: `num_train_steps` and `sample_1_of_n_eval_examples`.
#
# ## Run the experiment
#
# Now we need to create and run the experiment. First, we fetch the desired datasets, and combine these into train- and test sets. Note that we can provide multiple sets for both training and testing. Also note that each set consists of both a label and an image dataset.

# %%
# Load datasets

from azureml.core import Dataset

train_images = Dataset.get_by_name(workspace, name="Grogol_train_images")
train_labels = Dataset.get_by_name(workspace, name="Grogol_train_labels")
test_images = Dataset.get_by_name(workspace, name="Grogol_test_images")
test_labels = Dataset.get_by_name(workspace, name="Grogol_test_labels")

trainsets = [
    (train_labels, train_images),
]
testsets = [
    (test_labels, test_images)
]

checkpoint_files = Dataset.get_by_name(workspace, name="tf2od_checkpoints")

# %% [markdown]
# We now have everything we need to perform the run locally. Lets do so!

# %%
#checkpoint_files = Dataset.get_by_name(workspace, name="EfficientDetD0")

# %%
import os
# Impossible models to train because batch_size of 1 doesn't fit into memory 
impossible_to_train_models = [
    'efficientdet_d5', 
    'efficientdet_d6',
    'efficientdet_d7',
    'faster_rcnn_inception_resnet_v2_1024x1024',
    'faster_rcnn_resnet101_v1_800x1333',
    'faster_rcnn_resnet152_v1_800x1333',
    'faster_rcnn_resnet152_v1_1024x1024'    
]


model_names = sorted([f[:-7] for f in os.listdir('examples/tensorflow/tf2od/configs') if f.endswith('.config') 
                        and f[:-7] not in impossible_to_train_models])
print(len(model_names))
model_names
# Out:
# 31
# ['centernet_hg104_1024x1024',
#  'centernet_hg104_512x512',
#  'centernet_resnet101_v1_fpn_512x512',
#  'centernet_resnet50_v1_fpn_512x512',
#  'centernet_resnet50_v2_512x512',
#  'efficientdet_d0',
#  'efficientdet_d0_0',
#  'efficientdet_d0_1',
#  'efficientdet_d0_2',
#  'efficientdet_d0_3',
#  'efficientdet_d0_4',
#  'efficientdet_d0_5',
#  'efficientdet_d0_6',
#  'efficientdet_d1',
#  'efficientdet_d2',
#  'efficientdet_d3',
#  'efficientdet_d4',
#  'faster_rcnn_inception_resnet_v2_640x640',
#  'faster_rcnn_resnet101_v1_1024x1024',
#  'faster_rcnn_resnet101_v1_640x640',
#  'faster_rcnn_resnet152_v1_640x640',
#  'faster_rcnn_resnet50_v1_1024x1024',
#  'faster_rcnn_resnet50_v1_640x640',
#  'faster_rcnn_resnet50_v1_640x640 copy',
#  'faster_rcnn_resnet50_v1_800x1333',
#  'ssd_resnet101_v1_fpn_1024x1024',
#  'ssd_resnet101_v1_fpn_640x640',
#  'ssd_resnet152_v1_fpn_1024x1024',
#  'ssd_resnet152_v1_fpn_640x640',
#  'ssd_resnet50_v1_fpn_1024x1024',
#  'ssd_resnet50_v1_fpn_640x640']

# %%
from toc_azurewrapper.train import perform_run
import time

# Note, 1 step is 1 batch. With batch size of 1 and trainset of size 473, 1 epoch is 473 steps.

#model_name = 'efficientdet_d5'
model_name = 'faster_rcnn_resnet50_v1_640x640'
assert (model_name + '.config') in os.listdir('examples/tensorflow/tf2od/configs/')

# for config_num in range(0,1):
#     cuda_error_out_of_memory = True
#     while cuda_error_out_of_memory:

        
#         print(run._run_number)
#         tag = f"Initial tests {config_num}"
#         print(tag)
#         run.tag(tag)
#         display(run)
#         run.wait_for_completion()
        
#         time.sleep(10)
#         x = run.get_all_logs()
#         time.sleep(10)
#         with open([xx for xx in x if xx.endswith('70_driver_log.txt')][0], 'r') as f:
#             s = f.read()
#         f.close()
#         cuda_error_out_of_memory = ('CUDA_ERROR_OUT_OF_MEMORY' in s) or ('Resource exhausted: OOM when allocating tensor with shape' in s)

# %%
from toc_azurewrapper.train import perform_run
from azureml.core.runconfig import TensorflowConfiguration
import time

run = perform_run(experiment, 'train.py', 'examples/tensorflow', environment=environment,
                    trainsets=trainsets, testsets=testsets, compute_target=compute_target,
                    parameters={
                        'model_name': model_name,
                        'sample_1_of_n_eval_examples': 1,
                        'num_train_steps': 25000,
                        'checkpoint_files': checkpoint_files.as_named_input(f'checkpoint_files').as_mount(),
                              #'config_num': '_' + str(config_num)
                    },
                    #distributed_job_config=TensorflowConfiguration(worker_count=2, parameter_server_count=1)
                 )
run.wait_for_completion(show_output=True)
# Out:
# RunId: model-tf2od-jayke_1610629406_cefb7331
# Web View: https://ml.azure.com/experiments/model-tf2od-jayke/runs/model-tf2od-jayke_1610629406_cefb7331?wsid=/subscriptions/a00eaec6-b320-4e7c-ae61-60a30aec1cfc/resourcegroups/MachineLearning/workspaces/tutorial_azureml_mats
#
# Streaming azureml-logs/55_azureml-execution-tvmps_df64ad678115a5be4045276b2300ac5f8e1c56e7bcfe028be595a6f554b5bd34_d.txt
# ========================================================================================================================
#
# 2021-01-14T13:03:44Z Starting output-watcher...
# 2021-01-14T13:03:44Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-01-14T13:03:45Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-01-14T13:03:45Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_9d4fa30783fc98f2c7c7f19c6a312f30
# Digest: sha256:96a223a2d683aab4b4f91719ba3f705a79883c430ca39e73845fd2ba36704f14
# Status: Image is up to date for viennaglobal.azurecr.io/azureml/azureml_9d4fa30783fc98f2c7c7f19c6a312f30:latest
# viennaglobal.azurecr.io/azureml/azureml_9d4fa30783fc98f2c7c7f19c6a312f30:latest
# 2021-01-14T13:03:47Z Check if container model-tf2od-jayke_1610629406_cefb7331 already exist exited with 0,
#
# a462df7ca68d7035ae6a3f62f0d3b7ca3e8f44a5be88d4d33f0faf1a82140418
# 2021/01/14 13:03:49 Starting App Insight Logger for task:  containerSetup
# 2021/01/14 13:03:49 Version: 3.0.01467.0002 Branch: 70 Commit: 969f819
# 2021/01/14 13:03:49 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/01/14 13:03:49 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/01/14 13:03:49 sshd inside container not required for job, skipping setup.
# 2021/01/14 13:03:49 All App Insights Logs was send successfully
# 2021-01-14T13:03:49Z Starting docker container succeeded.
#
# Streaming azureml-logs/65_job_prep-tvmps_df64ad678115a5be4045276b2300ac5f8e1c56e7bcfe028be595a6f554b5bd34_d.txt
# ===============================================================================================================
#
# [2021-01-14T13:03:51.381815] Entering job preparation.
# [2021-01-14T13:03:51.625524] Starting job preparation.
# [2021-01-14T13:03:51.625562] Extracting the control code.
# [2021-01-14T13:03:51.654282] fetching and extracting the control code on master node.
# [2021-01-14T13:03:51.654307] Starting extract_project.
# [2021-01-14T13:03:51.654341] Starting to extract zip file.
# [2021-01-14T13:03:52.746014] Finished extracting zip file.
# [2021-01-14T13:03:53.004781] Using urllib.request Python 3.0 or later
# [2021-01-14T13:03:53.004839] Start fetching snapshots.
# [2021-01-14T13:03:53.004885] Start fetching snapshot.
# [2021-01-14T13:03:53.004900] Retrieving project from snapshot: 0ae202ca-3382-4a29-b2c6-c815f176a3f8
# Starting the daemon thread to refresh tokens in background for process with pid = 49
# [2021-01-14T13:03:56.313370] Finished fetching snapshot.
# [2021-01-14T13:03:56.313400] Finished fetching snapshots.
# [2021-01-14T13:03:56.313411] Finished extract_project.
# [2021-01-14T13:03:56.348826] Finished fetching and extracting the control code.
# [2021-01-14T13:03:56.354079] Start run_history_prep.
# [2021-01-14T13:03:56.605364] Job preparation is complete.
# [2021-01-14T13:03:56.605404] Entering Data Context Managers in Sidecar
# [2021-01-14T13:03:56.606613] Running Sidecar prep cmd...
# [2021-01-14T13:03:56.930398] DEBUG azureml.sidecar.try_add_control_script_to_path: Adding ES Control Scripts to sys.path: /mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/mounts/workspaceblobstore/azureml/model-tf2od-jayke_1610629406_cefb7331-setup
# [2021-01-14T13:03:56.931215] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "enter_contexts"
# [2021-01-14T13:03:56.931825] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "exit_contexts"
# [2021-01-14T13:03:56.941326] DEBUG azureml.sidecar.set_run_wd: Changing working dir to: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/mounts/workspaceblobstore/azureml/model-tf2od-jayke_1610629406_cefb7331
# [2021-01-14T13:03:56.942029] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/mounts/workspaceblobstore/azureml/model-tf2od-jayke_1610629406_cefb7331
# [2021-01-14T13:03:56.942343] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# [2021-01-14T13:03:56.942686] DEBUG azureml.sidecar.TaskRegistry.execute: Executing "enter_contexts"
# [2021-01-14T13:03:56.943190] DEBUG azureml.sidecar.TaskServerClient.__init__: Connecting to TaskServer at 127.0.0.1:39593
# [2021-01-14T13:03:56.943518] DEBUG azureml.sidecar.TaskRegistry.execute: Sending payload for "enter_contexts":
# {"host_secret": "4a302171-a7e4-41c3-9ee1-806a6d53842a", "task": "enter_contexts", "caller_session_id": "08a1c8a2-ec08-4061-af93-0f91227d0a82", "context_managers": ["Dataset:context_managers.Datasets"], "job_task_error_path": "/mnt/batch/tasks/workitems/7e808dab-9659-487a-8c64-a5a6412db29e/job-1/model-tf2od-jayke_16_76b35c0b-1996-4c6b-921f-e1217b67dda8/wd/runSpecialJobTask_error.json"}
# [2021-01-14T13:04:17.980349] DEBUG azureml.sidecar.TaskRegistry.execute: Received response for "enter_contexts": {"result": "success"}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.19.0 azureml-dataprep==2.6.4. Session id: 488c7680-e8e1-4ea5-a748-1e69bd4bf483. Run id: model-tf2od-jayke_1610629406_cefb7331.
# Processing 'checkpoint_files'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('modeldata', 'tf2od_checkpoints/**')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "cb22d5b8-7a41-4294-ad4d-1e71ec536c65",
#     "name": "tf2od_checkpoints",
#     "version": 1,
#     "description": "Tensorflow2 Object Detection checkpoint files",
#     "workspace": "Workspace.create(name='tutorial_azureml_mats', subscription_id='a00eaec6-b320-4e7c-ae61-60a30aec1cfc', resource_group='MachineLearning')"
#   }
# }
# Mounting checkpoint_files to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39.
# Mounted checkpoint_files to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39 as folder.
# Processing 'test_images_0'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('modeldata', 'plastic_test_extendedHV/**')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "10cb01b0-428b-4f12-a7f3-0dc998f77181",
#     "name": "Grogol_test_images",
#     "version": 2,
#     "workspace": "Workspace.create(name='tutorial_azureml_mats', subscription_id='a00eaec6-b320-4e7c-ae61-60a30aec1cfc', resource_group='MachineLearning')"
#   }
# }
# Mounting test_images_0 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof.
# Mounted test_images_0 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof as folder.
# Processing 'train_images_0'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('modeldata', 'plastic_train/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "9e0bf90c-7432-4774-80e7-039ca8e6dc4f",
#     "name": "Grogol_train_images",
#     "version": 1,
#     "workspace": "Workspace.create(name='tutorial_azureml_mats', subscription_id='a00eaec6-b320-4e7c-ae61-60a30aec1cfc', resource_group='MachineLearning')"
#   }
# }
# Mounting train_images_0 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmphb97yugt.
# Mounted train_images_0 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmphb97yugt as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset checkpoint_files's target path to /mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39
# Set Dataset test_images_0's target path to /mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof
# Set Dataset train_images_0's target path to /mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmphb97yugt
# Starting the daemon thread to refresh tokens in background for process with pid = 1
# [2021-01-14T13:04:15.679248] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-01-14T13:04:15.680412] DEBUG azureml.sidecar.task.enter_contexts: Added Keys: ['AZUREML_SIDECAR_PATHS_TO_BIND']
# [2021-01-14T13:04:15.680893] DEBUG azureml.sidecar.task.enter_contexts: Updated Keys: ['TEST_IMAGES_0', 'CHECKPOINT_FILES', 'AZUREML_DATAREFERENCE_checkpoint_files', 'train_images_0', 'checkpoint_files', 'AZUREML_DATAREFERENCE_test_images_0', 'test_images_0', 'AZUREML_DATAREFERENCE_train_images_0', 'TRAIN_IMAGES_0']
# [2021-01-14T13:04:15.688137] DEBUG azureml.sidecar.task.enter_contexts: Persisted env vars changed by ContextManagers
# [2021-01-14T13:04:15.688528] DEBUG azureml.sidecar.task.enter_contexts: Get File Access Control List for /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39
# [2021-01-14T13:04:15.915085] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_hg104_1024x1024.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.915950] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_hg104_1024x1024.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.916572] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_hg104_512x512.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.917152] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_hg104_512x512.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.917760] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_resnet101_v1_fpn_512x512.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.918351] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_resnet101_v1_fpn_512x512.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.918963] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_resnet50_v1_fpn_512x512.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.919561] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_resnet50_v1_fpn_512x512.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.920135] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_resnet50_v2_512x512.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.920711] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/centernet_resnet50_v2_512x512.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.921310] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d0.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.921887] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d0.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.922456] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d1.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.923046] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d1.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.923621] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d2.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.924196] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d2.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.924762] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d3.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.925347] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d3.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.925908] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d4.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.927179] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d4.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.927840] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d5.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.928566] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d5.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.929444] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d6.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.930283] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d6.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.931005] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d7.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.931618] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/efficientdet_d7.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.932326] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_inception_resnet_v2_1024x1024.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.932949] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_inception_resnet_v2_1024x1024.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.933541] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_inception_resnet_v2_640x640.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.934166] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_inception_resnet_v2_640x640.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.934791] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet101_v1_1024x1024.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.935392] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet101_v1_1024x1024.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.935982] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet101_v1_640x640.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.936585] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet101_v1_640x640.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.937192] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet101_v1_800x1333.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.937797] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet101_v1_800x1333.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.938456] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet152_v1_1024x1024.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.939059] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet152_v1_1024x1024.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.939641] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet152_v1_640x640.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.940223] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet152_v1_640x640.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.940794] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet152_v1_800x1333.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.941377] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet152_v1_800x1333.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.942442] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet50_v1_1024x1024.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.943084] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet50_v1_1024x1024.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.943844] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet50_v1_640x640.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.944518] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet50_v1_640x640.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.945471] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet50_v1_800x1333.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.946105] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/faster_rcnn_resnet50_v1_800x1333.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.946690] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet101_v1_fpn_1024x1024.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.947414] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet101_v1_fpn_1024x1024.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.948091] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet101_v1_fpn_640x640.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.948696] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet101_v1_fpn_640x640.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.949303] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet152_v1_fpn_1024x1024.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.949887] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet152_v1_fpn_1024x1024.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.950465] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet152_v1_fpn_640x640.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.951070] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet152_v1_fpn_640x640.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.951658] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet50_v1_fpn_1024x1024.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.952249] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet50_v1_fpn_1024x1024.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.952825] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet50_v1_fpn_640x640.data-00000-of-00001, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.953394] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpr5egng39/ssd_resnet50_v1_fpn_640x640.index, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:15.953783] DEBUG azureml.sidecar.task.enter_contexts: Get File Access Control List for /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof
# [2021-01-14T13:04:16.186149] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_1_2018-04-30 16-00-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.187053] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_1_2018-05-02 10-00-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.187749] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_1_2018-05-02 11-30-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.188367] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_1_2018-05-02 13-15-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.188963] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_1_2018-05-02 14-30-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.189551] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_1_2018-05-07 11-15-00-05_cam1.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.190133] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_1_2018-05-07 12-45-00-05_cam1.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.190745] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_1_2018-05-07 14-45-00-05_cam1.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.191339] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_1_2018-05-07 15-45-00-05_cam1.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.192360] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-04-30 14-30-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.192959] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-04-30 14-45-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.193555] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-02 13-45-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.194136] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-03 13-30-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.194736] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-03 14-15-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.195356] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-08 09-45-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.196020] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-08 14-00-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.196605] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-08 16-15-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.197195] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-08 16-30-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.197803] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-11 10-30-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.198385] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-11 11-15-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.198983] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-11 12-30-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.199588] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-11 14-45-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.200171] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-11 15-00-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.200747] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_2_2018-05-12 11-15-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.201362] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-04-30 14-30-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.201979] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-04-30 15-00-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.202567] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-02 10-00-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.203191] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-02 10-15-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.203775] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-02 11-00-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.204376] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-02 12-30-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.204973] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-02 13-00-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.205617] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-02 14-30-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.206203] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-03 11-00-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.206815] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-03 12-30-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.207481] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-03 15-00-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.208094] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-04 09-45-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.208761] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-04 14-00-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.209373] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-04 14-30-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.210003] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_3_2018-05-05 11-30-00-05_cam3.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.210595] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-04-30 14-30-00-05_cam10.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.211241] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-02 08-45-00-05_cam9.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.211842] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-03 11-15-00-05_cam9.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.212449] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-04 09-30-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.213042] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-04 10-30-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.213648] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-04 11-00-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.214284] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-04 13-00-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.214893] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-04 13-15-00-05_cam8.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.215468] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-05 13-00-00-05_cam4.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.216068] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-05 14-00-00-05_cam4.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.216673] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-08 14-15-00-05_cam4.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.217268] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-08 14-30-00-05_cam4.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.217860] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-08 15-15-00-05_cam4.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.218441] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/Grogol_Location_4_2018-05-11 13-15-00-05_cam4.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.219020] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_1_2018-04-30 16-00-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.219611] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_1_2018-05-02 10-00-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.220188] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_1_2018-05-02 11-30-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.220763] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_1_2018-05-02 13-15-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.221441] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_1_2018-05-02 14-30-00-05_cam6.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.222039] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_1_2018-05-07 11-15-00-05_cam1.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.222621] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_1_2018-05-07 12-45-00-05_cam1.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.223333] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_1_2018-05-07 14-45-00-05_cam1.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.223946] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_1_2018-05-07 15-45-00-05_cam1.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.224545] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_2_2018-04-30 14-30-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.225147] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_2_2018-04-30 14-45-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.225736] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_2_2018-05-02 13-45-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.226324] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_2_2018-05-03 13-30-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.226927] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_2_2018-05-03 14-15-00-05_cam7.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.227509] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_2_2018-05-08 09-45-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.228094] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_2_2018-05-08 14-00-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# [2021-01-14T13:04:16.228847] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/tutorial_azureml_mats/azureml/model-tf2od-jayke_1610629406_cefb7331/wd/tmpye_2ruof/HGrogol_Location_2_2018-05-08 16-15-00-05_cam2.jpg, ACL: 0o777, owner: root, group: root
# ...
# W0114 13:12:36.487781 140473687459648 deprecation.py:323] From /opt/miniconda/lib/python3.7/site-packages/object_detection/model_lib_v2.py:702: set_learning_phase (from tensorflow.python.keras.backend) is deprecated and will be removed after 2020-10-11.
# Instructions for updating:
# Simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0114 13:12:42.535030 140473687459648 convolutional_keras_box_predictor.py:154] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /opt/miniconda/lib/python3.7/site-packages/object_detection/utils/model_util.py:57: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0114 13:12:49.634332 140473687459648 deprecation.py:323] From /opt/miniconda/lib/python3.7/site-packages/object_detection/utils/model_util.py:57: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /opt/miniconda/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0114 13:12:54.473418 140473687459648 deprecation.py:323] From /opt/miniconda/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /opt/miniconda/lib/python3.7/site-packages/object_detection/eval_util.py:926: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0114 13:12:59.640186 140473687459648 deprecation.py:323] From /opt/miniconda/lib/python3.7/site-packages/object_detection/eval_util.py:926: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2021-01-14 13:13:05.377261: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-01-14 13:13:05.532728: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# INFO:tensorflow:Finished eval step 0
# I0114 13:13:08.311958 140473687459648 model_lib_v2.py:805] Finished eval step 0
# WARNING:tensorflow:From /opt/miniconda/lib/python3.7/site-packages/object_detection/utils/visualization_utils.py:617: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
# options available in V2.
# - tf.py_function takes a python function which manipulates tf eager
# tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
# an ndarray (just call tensor.numpy()) but having access to eager tensors
# means `tf.py_function`s can use accelerators such as GPUs as well as
# being differentiable using a gradient tape.
# - tf.numpy_function maintains the semantics of the deprecated tf.py_func
# (it is not differentiable, and manipulates numpy arrays). It drops the
# stateful argument making all functions stateful.
#
# W0114 13:13:08.472854 140473687459648 deprecation.py:323] From /opt/miniconda/lib/python3.7/site-packages/object_detection/utils/visualization_utils.py:617: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
# options available in V2.
# - tf.py_function takes a python function which manipulates tf eager
# tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
# an ndarray (just call tensor.numpy()) but having access to eager tensors
# means `tf.py_function`s can use accelerators such as GPUs as well as
# being differentiable using a gradient tape.
# - tf.numpy_function maintains the semantics of the deprecated tf.py_func
# (it is not differentiable, and manipulates numpy arrays). It drops the
# stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0114 13:13:41.038281 140473687459648 model_lib_v2.py:805] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0114 13:14:04.656824 140473687459648 model_lib_v2.py:805] Finished eval step 200
# INFO:tensorflow:Performing evaluation on 212 images.
# I0114 13:14:07.436153 140473687459648 coco_evaluation.py:282] Performing evaluation on 212 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0114 13:14:07.440730 140473687459648 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.03s)
# I0114 13:14:07.472660 140473687459648 coco_tools.py:138] DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=13.74s).
# Accumulating evaluation results...
# DONE (t=0.17s).
# Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
# Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
# Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
# Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
# Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
# Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
# Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
# Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
# Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# INFO:tensorflow:Eval metrics at step 0
# I0114 13:14:21.423654 140473687459648 model_lib_v2.py:860] Eval metrics at step 0
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.000000
# I0114 13:14:21.432335 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Precision/mAP: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.000000
# I0114 13:14:21.433304 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.000000
# I0114 13:14:21.434227 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.000000
# I0114 13:14:21.435175 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Precision/mAP (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.000000
# I0114 13:14:21.436094 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Precision/mAP (medium): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.000000
# I0114 13:14:21.437002 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Precision/mAP (large): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.000000
# I0114 13:14:21.437910 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Recall/AR@1: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.000000
# I0114 13:14:21.438862 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Recall/AR@10: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.000000
# I0114 13:14:21.439779 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Recall/AR@100: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# I0114 13:14:21.440690 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.000000
# I0114 13:14:21.441597 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.000000
# I0114 13:14:21.442567 140473687459648 model_lib_v2.py:863] 	+ DetectionBoxes_Recall/AR@100 (large): 0.000000
# INFO:tensorflow:	+ Loss/RPNLoss/localization_loss: 2.947363
# I0114 13:14:21.443409 140473687459648 model_lib_v2.py:863] 	+ Loss/RPNLoss/localization_loss: 2.947363
# INFO:tensorflow:	+ Loss/RPNLoss/objectness_loss: 0.683915
# I0114 13:14:21.444257 140473687459648 model_lib_v2.py:863] 	+ Loss/RPNLoss/objectness_loss: 0.683915
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/localization_loss: 0.000000
# I0114 13:14:21.445096 140473687459648 model_lib_v2.py:863] 	+ Loss/BoxClassifierLoss/localization_loss: 0.000000
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/classification_loss: 0.871377
# I0114 13:14:21.445934 140473687459648 model_lib_v2.py:863] 	+ Loss/BoxClassifierLoss/classification_loss: 0.871377
# INFO:tensorflow:	+ Loss/regularization_loss: 0.000000
# I0114 13:14:21.446785 140473687459648 model_lib_v2.py:863] 	+ Loss/regularization_loss: 0.000000
# INFO:tensorflow:	+ Loss/total_loss: 4.502652
# DEBUG - Done measuring performance
# DEBUG - Registering performance data
# 2021-01-14 13:14:22.138906: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-14 13:14:24.088121: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-01-14 13:14:24.119580: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0001:00:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-01-14 13:14:24.119685: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-14 13:14:24.121484: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-01-14 13:14:24.123196: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-01-14 13:14:24.123513: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-01-14 13:14:24.125303: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-01-14 13:14:24.126344: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-01-14 13:14:24.130345: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-01-14 13:14:24.131820: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-01-14 13:14:24.132199: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-01-14 13:14:24.139515: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2596995000 Hz
# 2021-01-14 13:14:24.140304: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5559f62333f0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-01-14 13:14:24.140358: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-01-14 13:14:24.191737: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5559f62bf5d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-01-14 13:14:24.191831: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2021-01-14 13:14:24.192743: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0001:00:00.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2021-01-14 13:14:24.192828: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-14 13:14:24.192910: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-01-14 13:14:24.192972: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-01-14 13:14:24.193033: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-01-14 13:14:24.193092: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-01-14 13:14:24.193146: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-01-14 13:14:24.193201: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-01-14 13:14:24.194582: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-01-14 13:14:24.194643: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-14 13:14:24.665921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-14 13:14:24.666048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2021-01-14 13:14:24.666115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2021-01-14 13:14:24.667818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10617 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0001:00:00.0, compute capability: 3.7)
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0114 13:14:29.897216 140699654309696 convolutional_keras_box_predictor.py:154] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /opt/miniconda/lib/python3.7/site-packages/object_detection/utils/model_util.py:57: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0114 13:14:37.028664 140699654309696 deprecation.py:323] From /opt/miniconda/lib/python3.7/site-packages/object_detection/utils/model_util.py:57: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.faster_rcnn_meta_arch.FasterRCNNMetaArch object at 0x7ff6d11c0110>, because it is not built.
# W0114 13:14:44.421559 140699654309696 save_impl.py:78] Skipping full serialization of Keras layer <object_detection.meta_architectures.faster_rcnn_meta_arch.FasterRCNNMetaArch object at 0x7ff6d11c0110>, because it is not built.
# 2021-01-14 13:14:52.384937: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %% [markdown]
# Finally, if the result is to our liking, we will register the model. This means we can use it for deployment. Provide a name to the model, the path to either a single artifact or to the folder containing all required artifacts, and optionally a description, properties and tags.

# %%
run.register_model(
    "frcnn",
    model_path="outputs/",
    description="FRCNN implementation on Tensorflow + Object detection API",
    properties={
        "location": "there",
        "time": "noon"
    }
)

# %%
python model_main_tf2.py --model_dir=models/my_EfficientDetD0/ --pipeline_config_path=models/my_EfficientDetD0/pipeline.config
